# %% [markdown]
# ## Welcome to your notebook.

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %% [markdown]
# #### Now you are ready to start!

# %%
###Install the correct libraries via pip or conda then run this part of the code

# %%
#Name: PRISMA2GeoTIFF.py
#Description: reads he5 PRISMA files content and converts it to a GeoTIFF.
#All 66 VNIR bands and 173 SWIR bands are converted in one single GeoTIFF file.
#input is a PRISMA he5 file and output is a GeoTIFF with the same name in the same path
#Author: martin rapilly, mrapilly60@uasd.edu.do/martin.rapilly@get.omp.eu

#import libraries
import h5py
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
from itertools import chain
from osgeo import gdal, osr
import os

# %%
###Run this code to initiate the function PRISMA2GeoTIFF

# %%
#np.set_printoptions(threshold=np.inf)#optional: uncommenting this line will show full arrays when printing on the console. Not recommended as he5 PRISMA files contain many values that can overrun memory

def PRISMA2GeoTIFF (filename):
    #open he5 file and read its content
    f = h5py.File(filename,'r')
    def print_name(name, obj):
        if isinstance(obj, h5py.Dataset):
            print ('Dataset:', name)
        elif isinstance(obj, h5py.Group):
            print ('Group:', name)
    with h5py.File(filename, 'r')  as h5f: # file will be closed when we exit from WITH scope
        h5f.visititems(print_name)

    
        #read SWIR and VNIR cube contents
        '''SWIRcube = h5f['HDFEOS/SWATHS/PRS_L2D_HCO/Data Fields/SWIR_Cube'][()]#[()] is to get the value. Can be replaced with .value
        VNIRcube = h5f['HDFEOS/SWATHS/PRS_L2D_HCO/Data Fields/VNIR_Cube'][()]
    
        #read latitude and longitude contents
        lat = h5f['HDFEOS/SWATHS/PRS_L2D_HCO/Geolocation Fields/Latitude'][()]
        lon = h5f['HDFEOS/SWATHS/PRS_L2D_HCO/Geolocation Fields/Longitude'][()]'''


        def first_existing(h5f, paths):
            for p in paths:
                if p in h5f:
                    return p
            return None

        # --- detect which PRISMA swath exists (L1 vs L2D, HCO vs HRC) ---
        swath = first_existing(h5f, [
            "HDFEOS/SWATHS/PRS_L2D_HCO",
            "HDFEOS/SWATHS/PRS_L2D_HRC",
            "HDFEOS/SWATHS/PRS_L1_HCO",
            "HDFEOS/SWATHS/PRS_L1_HRC",
        ])
        if swath is None:
            raise KeyError("No PRISMA swath found under HDFEOS/SWATHS (expected PRS_L1_* or PRS_L2D_*).")
        
        # --- group names can be 'Data Fields' or 'Data_Fields' (underscore) ---
        data_fields = first_existing(h5f, [f"{swath}/Data Fields", f"{swath}/Data_Fields"])
        if data_fields is None:
            raise KeyError(f"Found swath {swath} but no Data Fields group.")
        
        geo_fields  = first_existing(h5f, [f"{swath}/Geolocation Fields", f"{swath}/Geolocation_Fields"])
        if geo_fields is None:
            raise KeyError(f"Found swath {swath} but no Geolocation Fields group.")
        
        # --- datasets ---
        swir_path = first_existing(h5f, [f"{data_fields}/SWIR_Cube"])
        vnir_path = first_existing(h5f, [f"{data_fields}/VNIR_Cube"])
        # --- PRISMA L1 has spectrometer-specific geolocation ---
        lat_path = first_existing(h5f, [
            f"{geo_fields}/Latitude_VNIR",
            f"{geo_fields}/Latitude_SWIR",
        ])
        lon_path = first_existing(h5f, [
            f"{geo_fields}/Longitude_VNIR",
            f"{geo_fields}/Longitude_SWIR",
        ])
        
        if lat_path is None or lon_path is None:
            raise KeyError(
                f"No usable Latitude/Longitude found. "
                f"Available: {list(h5f[geo_fields].keys())}"
            )
        
        lat = h5f[lat_path][()]
        lon = h5f[lon_path][()]
        
        print("Using geolocation:", lat_path, lon_path)
                
        missing = [name for name, p in [("SWIR_Cube", swir_path), ("VNIR_Cube", vnir_path), ("Latitude", lat_path), ("Longitude", lon_path)] if p is None]
        if missing:
            # show what exists to help you map names
            available_df  = list(h5f[data_fields].keys()) if data_fields in h5f else []
            available_geo = list(h5f[geo_fields].keys()) if geo_fields in h5f else []
            raise KeyError(f"Missing {missing}. DataFields has: {available_df}. Geolocation has: {available_geo}.")
        
        # --- read arrays ---
        SWIRcube = h5f[swir_path][()]
        VNIRcube = h5f[vnir_path][()]
        lat      = h5f[lat_path][()]
        lon      = h5f[lon_path][()]
        
        print("Using swath:", swath)
        print("SWIR path:", swir_path)
        print("VNIR path:", vnir_path)
        print("LAT/LON paths:", lat_path, lon_path)
        


        
        #checks SWIR, VNIR and latitude/longitude array shapes
        print ("SWIRcube.shape",SWIRcube.shape)
        print ("VNIRcube.shape",VNIRcube.shape)
        print ("lat.shape",lat.shape)        
        
        #create lists from latitude/longitude values
        lonIter=list(chain.from_iterable(lon))
        latIter=list(chain.from_iterable(lat))


        
        
        #create a list from VNIR and SWIR cube values
        listBand=[]
        for band in range(0,VNIRcube.shape[1]):#VNIRcube.shape[1] gives the number of bands (:66)
            for x in range(0,lat.shape[0]):#lat.shape[0] gives the number of rows
                element=VNIRcube[x][band]
                listBand.append(element)
        for band1 in range(0,SWIRcube.shape[1]):#SWIRcube.shape[1] gives the number of bands (:137)
            for x1 in range(0,lat.shape[0]):#lat.shape[0] gives the number of rows
                element=SWIRcube[x1][band1]
                listBand.append(element)

        #convert list with values to a numpy array      
        data=np.array(listBand,dtype=np.uint16)

        #checks array shape
        print ("data.shape",data.shape)

        #reshape numpy array with the right number of bands, rows and columns
        dataReshaped=data.reshape([VNIRcube.shape[1]+SWIRcube.shape[1], lat.shape[0], lat.shape[1]])
        print ("reshaped data.shape",dataReshaped.shape)

        #get minimum and maximum latitude and longitude
        xmin,ymin,xmax,ymax = [lon.min(),lat.min(),lon.max(),lat.max()]

        #get pixel spatial resolution
        xres = (xmax-xmin)/lat.shape[1]#lat.shape[1] gives the number of cols
        yres = (ymax-ymin)/lat.shape[0]#lat.shape[0] gives the number of rows

        #define coordinates
        geotransform=(xmin,xres,0,ymax,0, -yres)#zeros (third and fifth parameters) are for rotation

        #define GeoTIFF structure and output filename
        output_raster = gdal.GetDriverByName('GTiff').Create(filename [:-3]+"tif",lat.shape[1], lat.shape[0], VNIRcube.shape[1]+SWIRcube.shape[1] ,gdal.GDT_Float32)  # Open the file
        
        #loop over all bands and write it to the GeoTIFF
        for b in range(1,VNIRcube.shape[1]+SWIRcube.shape[1]):
            print("converting band",b)
            outband = output_raster.GetRasterBand(b) 
            outband.WriteArray(dataReshaped[b,:,:])
        #specify coordinates to WGS84
        output_raster.SetGeoTransform(geotransform)  
        srs = osr.SpatialReference()                 
        srs.ImportFromEPSG(4326)                                                               
        output_raster.SetProjection(srs.ExportToWkt())

        #clean memory     
        output_raster.FlushCache()
        print("Conversion from he5 PRISMA file to GeoTIFF complete.")

# %%
###Put one or many files in a folder. Modify the folder path and run this part of the code:

# %%
#enter folder path with he5 PRISMA files in it
folderPath= r"C:\Users\smclaugh1\OneDrive - Freeport-McMoRan Inc\projects_2026\PRISMA\PRS_L2D_STD_20241213102717_20241213102721_0001"
listImages=[]
for file in os.listdir(folderPath):
      listImages.append(os.path.join(folderPath, file))
print ("he5 image list: ", listImages)

#apply function PRISMA2GeoTIFF
for filename in listImages:
    print("Processing image", filename)
    PRISMA2GeoTIFF(filename)
print ("All files processed.")
# Out:
# he5 image list:  ['C:\\Users\\smclaugh1\\OneDrive - Freeport-McMoRan Inc\\projects_2026\\PRISMA\\PRS_L1_STD_OFFL_20210302034052_20210302034056_0001\\PRS_L1_STD_OFFL_20210302034052_20210302034056_0001.he5']
# Processing image C:\Users\smclaugh1\OneDrive - Freeport-McMoRan Inc\projects_2026\PRISMA\PRS_L1_STD_OFFL_20210302034052_20210302034056_0001\PRS_L1_STD_OFFL_20210302034052_20210302034056_0001.he5
# Group: HDFEOS
# Group: HDFEOS/ADDITIONAL
# Group: HDFEOS/ADDITIONAL/FILE_ATTRIBUTES
# Group: HDFEOS/SWATHS
# Group: HDFEOS/SWATHS/PRS_L1_HCO
# Group: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields/Cloud_Mask
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields/FrameNumber
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields/LandCover_Mask
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields/SWIR_Cube
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields/SWIR_PIXEL_SAT_ERR_MATRIX
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields/SunGlint_Mask
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields/VNIR_Cube
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields/VNIR_PIXEL_SAT_ERR_MATRIX
# Group: HDFEOS/SWATHS/PRS_L1_HCO/Geolocation Fields
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Geolocation Fields/Latitude_SWIR
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Geolocation Fields/Latitude_VNIR
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Geolocation Fields/Longitude_SWIR
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Geolocation Fields/Longitude_VNIR
# Dataset: HDFEOS/SWATHS/PRS_L1_HCO/Geolocation Fields/Time
# Group: HDFEOS/SWATHS/PRS_L1_HRC
# Group: HDFEOS/SWATHS/PRS_L1_HRC/Data Fields
# Dataset: HDFEOS/SWATHS/PRS_L1_HRC/Data Fields/FrameNumber
# Dataset: HDFEOS/SWATHS/PRS_L1_HRC/Data Fields/SWIR_Cube
# Dataset: HDFEOS/SWATHS/PRS_L1_HRC/Data Fields/SWIR_PIXEL_SAT_ERR_MATRIX
# Dataset: HDFEOS/SWATHS/PRS_L1_HRC/Data Fields/VNIR_Cube
# Dataset: HDFEOS/SWATHS/PRS_L1_HRC/Data Fields/VNIR_PIXEL_SAT_ERR_MATRIX
# Group: HDFEOS/SWATHS/PRS_L1_HRC/Geolocation Fields
# Dataset: HDFEOS/SWATHS/PRS_L1_HRC/Geolocation Fields/Latitude_SWIR
# Dataset: HDFEOS/SWATHS/PRS_L1_HRC/Geolocation Fields/Latitude_VNIR
# Dataset: HDFEOS/SWATHS/PRS_L1_HRC/Geolocation Fields/Longitude_SWIR
# Dataset: HDFEOS/SWATHS/PRS_L1_HRC/Geolocation Fields/Longitude_VNIR
# Dataset: HDFEOS/SWATHS/PRS_L1_HRC/Geolocation Fields/Time
# Group: HDFEOS/SWATHS/PRS_L1_PCO
# Group: HDFEOS/SWATHS/PRS_L1_PCO/Data Fields
# Dataset: HDFEOS/SWATHS/PRS_L1_PCO/Data Fields/Cube
# Dataset: HDFEOS/SWATHS/PRS_L1_PCO/Data Fields/FrameNumber
# Dataset: HDFEOS/SWATHS/PRS_L1_PCO/Data Fields/PIXEL_SAT_ERR_MATRIX
# Group: HDFEOS/SWATHS/PRS_L1_PCO/Geolocation Fields
# Dataset: HDFEOS/SWATHS/PRS_L1_PCO/Geolocation Fields/Latitude
# Dataset: HDFEOS/SWATHS/PRS_L1_PCO/Geolocation Fields/Longitude
# Dataset: HDFEOS/SWATHS/PRS_L1_PCO/Geolocation Fields/Time
# Group: HDFEOS/SWATHS/PRS_L1_PRC
# Group: HDFEOS/SWATHS/PRS_L1_PRC/Data Fields
# Dataset: HDFEOS/SWATHS/PRS_L1_PRC/Data Fields/Cube
# Dataset: HDFEOS/SWATHS/PRS_L1_PRC/Data Fields/FrameNumber
# Dataset: HDFEOS/SWATHS/PRS_L1_PRC/Data Fields/PIXEL_SAT_ERR_MATRIX
# Group: HDFEOS/SWATHS/PRS_L1_PRC/Geolocation Fields
# Dataset: HDFEOS/SWATHS/PRS_L1_PRC/Geolocation Fields/Latitude
# Dataset: HDFEOS/SWATHS/PRS_L1_PRC/Geolocation Fields/Longitude
# Dataset: HDFEOS/SWATHS/PRS_L1_PRC/Geolocation Fields/Time
# Group: HDFEOS INFORMATION
# Dataset: HDFEOS INFORMATION/StructMetadata.0
# Group: Info
# Group: Info/Ancillary
# Group: Info/Ancillary/GyroData
# Dataset: Info/Ancillary/GyroData/Gyro_1_data_angle
# Dataset: Info/Ancillary/GyroData/Gyro_1_data_byte
# Dataset: Info/Ancillary/GyroData/Gyro_2_data_angle
# Dataset: Info/Ancillary/GyroData/Gyro_2_data_byte
# Dataset: Info/Ancillary/GyroData/Gyro_3_data_angle
# Dataset: Info/Ancillary/GyroData/Gyro_3_data_byte
# Dataset: Info/Ancillary/GyroData/Gyro_4_data_angle
# Dataset: Info/Ancillary/GyroData/Gyro_4_data_byte
# Dataset: Info/Ancillary/GyroData/Gyro_5_data_angle
# Dataset: Info/Ancillary/GyroData/Gyro_5_data_byte
# Dataset: Info/Ancillary/GyroData/Gyro_6_data_angle
# Dataset: Info/Ancillary/GyroData/Gyro_6_data_byte
# Dataset: Info/Ancillary/GyroData/Star_sensors__Gyros_Data_validity
# Group: Info/Ancillary/PVSdata
# Dataset: Info/Ancillary/PVSdata/AOCS_Stat
# Dataset: Info/Ancillary/PVSdata/Clock_Bias
# Dataset: Info/Ancillary/PVSdata/Clock_Bias_Rate
# Dataset: Info/Ancillary/PVSdata/GPS_OBDH_Synch_Status
# Dataset: Info/Ancillary/PVSdata/GPS_Time_of_Last_Position
# Dataset: Info/Ancillary/PVSdata/Gdop
# Dataset: Info/Ancillary/PVSdata/Number_of_Satellites
# Dataset: Info/Ancillary/PVSdata/Position_Fix_Validity
# Dataset: Info/Ancillary/PVSdata/Week_Number
# Dataset: Info/Ancillary/PVSdata/Wgs84_pos_x
# Dataset: Info/Ancillary/PVSdata/Wgs84_pos_y
# Dataset: Info/Ancillary/PVSdata/Wgs84_pos_z
# Dataset: Info/Ancillary/PVSdata/Wgs84_vel_x
# Dataset: Info/Ancillary/PVSdata/Wgs84_vel_y
# Dataset: Info/Ancillary/PVSdata/Wgs_84_vel_z
# Group: Info/Ancillary/StarTracker1
# Dataset: Info/Ancillary/StarTracker1/NAV_ALG_values
# Dataset: Info/Ancillary/StarTracker1/NAV_APROP_EKF_values
# Dataset: Info/Ancillary/StarTracker1/NAV_ENA_values
# Dataset: Info/Ancillary/StarTracker1/Navigation_time
# Dataset: Info/Ancillary/StarTracker1/q_ECI_2_Body_1
# Dataset: Info/Ancillary/StarTracker1/q_ECI_2_Body_2
# Dataset: Info/Ancillary/StarTracker1/q_ECI_2_Body_3
# Dataset: Info/Ancillary/StarTracker1/q_ECI_2_Body_4
# Dataset: Info/Ancillary/StarTracker1/w_body_1
# Dataset: Info/Ancillary/StarTracker1/w_body_2
# Dataset: Info/Ancillary/StarTracker1/w_body_3
# Group: Info/Ancillary/StarTracker2
# Dataset: Info/Ancillary/StarTracker2/Attitude_status_ss
# Dataset: Info/Ancillary/StarTracker2/Data_valid_ss
# Dataset: Info/Ancillary/StarTracker2/Omega_x_ss
# Dataset: Info/Ancillary/StarTracker2/Omega_y_ss
# Dataset: Info/Ancillary/StarTracker2/Omega_z_ss
# Dataset: Info/Ancillary/StarTracker2/Quaternion_1_ss
# Dataset: Info/Ancillary/StarTracker2/Quaternion_2_ss
# Dataset: Info/Ancillary/StarTracker2/Quaternion_3_ss
# Dataset: Info/Ancillary/StarTracker2/Quaternion_4_ss
# Dataset: Info/Ancillary/StarTracker2/Time_day_ss
# Dataset: Info/Ancillary/StarTracker2/Time_msec_ss
# Group: Info/Header
# Dataset: Info/Header/FrameNumber
# Dataset: Info/Header/Frame_Corrupted
# Dataset: Info/Header/Frame_Missing
# Group: Info/Housekeeping
# Dataset: Info/Housekeeping/FPA_PAN_T
# Dataset: Info/Housekeeping/FPA_PAN_T1
# Dataset: Info/Housekeeping/FPA_PAN_T2
# Dataset: Info/Housekeeping/FPA_PT1000_SWIR_T
# Dataset: Info/Housekeeping/FPA_PT1000_VNIR_T
# Dataset: Info/Housekeeping/FPA_SWIR_T
# Dataset: Info/Housekeeping/FPA_SWIR_T1
# Dataset: Info/Housekeeping/FPA_SWIR_T2
# Dataset: Info/Housekeeping/FPA_VNIR_T
# Dataset: Info/Housekeeping/FPA_VNIR_T1
# Dataset: Info/Housekeeping/FPA_VNIR_T2
# Dataset: Info/Housekeeping/HEAT_PIPE_SWIR_T
# Dataset: Info/Housekeeping/HEAT_PIPE_VNIR_T
# Dataset: Info/Housekeeping/HK_UTC_Time
# Dataset: Info/Housekeeping/ICU_T
# Dataset: Info/Housekeeping/I_PHOTODIODE_SAFETY
# Dataset: Info/Housekeeping/I_PHOTODIODE_SIGNAL
# Dataset: Info/Housekeeping/I_PhotoDiode_High_Rate_Sample
# Dataset: Info/Housekeeping/LAMPS_T
# Dataset: Info/Housekeeping/LEDS_T
# Dataset: Info/Housekeeping/LOW_CARTER_T
# Dataset: Info/Housekeeping/MAIN_PORT_EMERGENCY_EN
# Dataset: Info/Housekeeping/MAIN_PORT_LOCK_EN
# Dataset: Info/Housekeeping/PAN_PEV3_3
# Dataset: Info/Housekeeping/PAN_PE_ERR
# Dataset: Info/Housekeeping/PAN_PE_STATUS1
# Dataset: Info/Housekeeping/PAN_PE_STATUS2
# Dataset: Info/Housekeeping/PAN_PE_V13DR
# Dataset: Info/Housekeeping/PAN_PE_V18_5
# Dataset: Info/Housekeeping/PAN_PE_V6_5
# Dataset: Info/Housekeeping/PAN_PE_V_6_5
# Dataset: Info/Housekeeping/PE_PAN_T
# Dataset: Info/Housekeeping/PE_SWIR_T
# Dataset: Info/Housekeeping/PE_VNIR_T
# Dataset: Info/Housekeeping/POSITON_SOLAR_PORT_MAIN_COVER_HES
# Dataset: Info/Housekeeping/POS_POT
# Dataset: Info/Housekeeping/PRISM_SWIR_T2
# Dataset: Info/Housekeeping/PRISM_VNIR_T1
# Dataset: Info/Housekeeping/PSR_VOLT_28V
# Dataset: Info/Housekeeping/PS_VOLT_28V
# Dataset: Info/Housekeeping/PS_VOLT_3_3V
# Dataset: Info/Housekeeping/PS_VOLT_5V
# Dataset: Info/Housekeeping/PS_VOLT_6V
# Dataset: Info/Housekeeping/PS_VOLT_MINUS_15V
# Dataset: Info/Housekeeping/PS_VOLT_PLUS_15V
# Dataset: Info/Housekeeping/PhotoDiode_High_Rate_Section
# Dataset: Info/Housekeeping/RADIATOR_SWIR
# Dataset: Info/Housekeeping/RADIATOR_VNIR
# Dataset: Info/Housekeeping/RTC_C_2W_1
# Dataset: Info/Housekeeping/RTC_C_2W_2
# Dataset: Info/Housekeeping/RTC_C_4W_1
# Dataset: Info/Housekeeping/RTC_C_4W_2
# Dataset: Info/Housekeeping/SDAC_COMP
# Dataset: Info/Housekeeping/SDAC_HEALTH
# Dataset: Info/Housekeeping/SDAC_PRI_COM
# Dataset: Info/Housekeeping/SEC_COM
# Dataset: Info/Housekeeping/SOLAR_PORT_EMERGENCY_EN
# Dataset: Info/Housekeeping/SPECT_T
# Dataset: Info/Housekeeping/SPECT_T1
# Dataset: Info/Housekeeping/SPECT_T2
# Dataset: Info/Housekeeping/SPECT_T3
# Dataset: Info/Housekeeping/SPS_STATUS
# Dataset: Info/Housekeeping/SWIR_PE_6_5PWR
# Dataset: Info/Housekeeping/SWIR_PE_ERR
# Dataset: Info/Housekeeping/SWIR_PE_STATUS1
# Dataset: Info/Housekeeping/SWIR_PE_STATUS2
# Dataset: Info/Housekeeping/SWIR_PE_VDD
# Dataset: Info/Housekeeping/SWIR_PE_VDDA
# Dataset: Info/Housekeeping/SWIR_PE_VDDO
# Dataset: Info/Housekeeping/SWIR_PE_VDET
# Dataset: Info/Housekeeping/SW_MODE
# Dataset: Info/Housekeeping/SW_PREMODE
# Dataset: Info/Housekeeping/SYNCHRO_STATUS
# Dataset: Info/Housekeeping/TMA_M1_T
# Dataset: Info/Housekeeping/TMA_M2_T
# Dataset: Info/Housekeeping/TMA_M3_T
# Dataset: Info/Housekeeping/TMA_T1
# Dataset: Info/Housekeeping/TMA_T2
# Dataset: Info/Housekeeping/TMA_T3
# Dataset: Info/Housekeeping/TM_ES_OPPOSITE_SIDE_SA_BA
# Dataset: Info/Housekeeping/TM_ES_SIDE_SA_BA
# Dataset: Info/Housekeeping/TOD_STATUS
# Dataset: Info/Housekeeping/UP_CARTER_T
# Dataset: Info/Housekeeping/VNIR_PE_6_5PWR
# Dataset: Info/Housekeeping/VNIR_PE_ERR
# Dataset: Info/Housekeeping/VNIR_PE_STATUS1
# Dataset: Info/Housekeeping/VNIR_PE_STATUS2
# Dataset: Info/Housekeeping/VNIR_PE_VDD
# Dataset: Info/Housekeeping/VNIR_PE_VDDA
# Dataset: Info/Housekeeping/VNIR_PE_VDDO
# Dataset: Info/Housekeeping/VNIR_PE_VDET
# Dataset: Info/Housekeeping/V_LAMP
# Dataset: Info/Housekeeping/V_LED
# Group: KDP_AUX
# Dataset: KDP_AUX/Cw_Swir_Matrix
# Dataset: KDP_AUX/Cw_Vnir_Matrix
# Dataset: KDP_AUX/Fwhm_Swir_Matrix
# Dataset: KDP_AUX/Fwhm_Vnir_Matrix
# Dataset: KDP_AUX/LOS_Pan
# Dataset: KDP_AUX/LOS_Swir
# Dataset: KDP_AUX/LOS_Vnir
# Using geolocation: HDFEOS/SWATHS/PRS_L1_HCO/Geolocation Fields/Latitude_VNIR HDFEOS/SWATHS/PRS_L1_HCO/Geolocation Fields/Longitude_VNIR
# Using swath: HDFEOS/SWATHS/PRS_L1_HCO
# SWIR path: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields/SWIR_Cube
# VNIR path: HDFEOS/SWATHS/PRS_L1_HCO/Data Fields/VNIR_Cube
# LAT/LON paths: HDFEOS/SWATHS/PRS_L1_HCO/Geolocation Fields/Latitude_VNIR HDFEOS/SWATHS/PRS_L1_HCO/Geolocation Fields/Longitude_VNIR
# SWIRcube.shape (1000, 173, 1000)
# VNIRcube.shape (1000, 66, 1000)
# lat.shape (1000, 1000)
# data.shape (239000, 1000)
# reshaped data.shape (239, 1000, 1000)
# converting band 1
# converting band 2
# converting band 3
# converting band 4
# converting band 5
# converting band 6
# converting band 7
# converting band 8
# converting band 9
# converting band 10
# converting band 11
# converting band 12
# converting band 13
# converting band 14
# converting band 15
# converting band 16
# converting band 17
# converting band 18
# converting band 19
# converting band 20
# converting band 21
# converting band 22
# converting band 23
# converting band 24
# converting band 25
# converting band 26
# converting band 27
# converting band 28
# converting band 29
# converting band 30
# converting band 31
# converting band 32
# converting band 33
# converting band 34
# converting band 35
# converting band 36
# converting band 37
# converting band 38
# converting band 39
# converting band 40
# converting band 41
# converting band 42
# converting band 43
# converting band 44
# converting band 45
# converting band 46
# converting band 47
# converting band 48
# converting band 49
# converting band 50
# converting band 51
# converting band 52
# converting band 53
# converting band 54
# converting band 55
# converting band 56
# converting band 57
# converting band 58
# converting band 59
# converting band 60
# converting band 61
# converting band 62
# converting band 63
# converting band 64
# converting band 65
# converting band 66
# converting band 67
# converting band 68
# converting band 69
# converting band 70
# converting band 71
# converting band 72
# C:\Users\smclaugh1\AppData\Local\anaconda3\Lib\site-packages\osgeo\gdal.py:330: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# converting band 73
# converting band 74
# converting band 75
# converting band 76
# converting band 77
# converting band 78
# converting band 79
# converting band 80
# converting band 81
# converting band 82
# converting band 83
# converting band 84
# converting band 85
# converting band 86
# converting band 87
# converting band 88
# converting band 89
# converting band 90
# converting band 91
# converting band 92
# converting band 93
# converting band 94
# converting band 95
# converting band 96
# converting band 97
# converting band 98
# converting band 99
# converting band 100
# converting band 101
# converting band 102
# converting band 103
# converting band 104
# converting band 105
# converting band 106
# converting band 107
# converting band 108
# converting band 109
# converting band 110
# converting band 111
# converting band 112
# converting band 113
# converting band 114
# converting band 115
# converting band 116
# converting band 117
# converting band 118
# converting band 119
# converting band 120
# converting band 121
# converting band 122
# converting band 123
# converting band 124
# converting band 125
# converting band 126
# converting band 127
# converting band 128
# converting band 129
# converting band 130
# converting band 131
# converting band 132
# converting band 133
# converting band 134
# converting band 135
# converting band 136
# converting band 137
# converting band 138
# converting band 139
# converting band 140
# converting band 141
# converting band 142
# converting band 143
# converting band 144
# converting band 145
# converting band 146
# converting band 147
# converting band 148
# converting band 149
# converting band 150
# converting band 151
# converting band 152
# converting band 153
# converting band 154
# converting band 155
# converting band 156
# converting band 157
# converting band 158
# converting band 159
# converting band 160
# converting band 161
# converting band 162
# converting band 163
# converting band 164
# converting band 165
# converting band 166
# converting band 167
# converting band 168
# converting band 169
# converting band 170
# converting band 171
# converting band 172
# converting band 173
# converting band 174
# converting band 175
# converting band 176
# converting band 177
# converting band 178
# converting band 179
# converting band 180
# converting band 181
# converting band 182
# converting band 183
# converting band 184
# converting band 185
# converting band 186
# converting band 187
# converting band 188
# converting band 189
# converting band 190
# converting band 191
# converting band 192
# converting band 193
# converting band 194
# converting band 195
# converting band 196
# converting band 197
# converting band 198
# converting band 199
# converting band 200
# converting band 201
# converting band 202
# converting band 203
# converting band 204
# converting band 205
# converting band 206
# converting band 207
# converting band 208
# converting band 209
# converting band 210
# converting band 211
# converting band 212
# converting band 213
# converting band 214
# converting band 215
# converting band 216
# converting band 217
# converting band 218
# converting band 219
# converting band 220
# converting band 221
# converting band 222
# converting band 223
# converting band 224
# converting band 225
# converting band 226
# converting band 227
# converting band 228
# converting band 229
# converting band 230
# converting band 231
# converting band 232
# converting band 233
# converting band 234
# converting band 235
# converting band 236
# converting band 237
# converting band 238
# Conversion from he5 PRISMA file to GeoTIFF complete.
# All files processed.
